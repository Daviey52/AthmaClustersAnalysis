# %%
import pandas as pd
import numpy as np
import os
import glob
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# Specify the directory containing the Excel files
directory_path = '/mnt/c/2024-Data/SCH_asthma_114'  # Replace with your directory path

# Find all Excel files in the directory
excel_files = glob.glob(os.path.join(directory_path, '*.xlsx'))

# List to store data from all files
all_data = []

# Loop over each Excel file and append data to the list
for file_path in excel_files:
    print(f"Processing file: {file_path}")
    
    # Step 1: Read the Excel file with error handling
    try:
        df = pd.read_excel(file_path, engine='openpyxl', skiprows=2)
    except Exception as e:
        print(f"Error reading {file_path}: {e}. Skipping this file.")
        continue  # Skip to the next file if there's an error

    # Define possible column names
    possible_columns = ['A01', 'A04', 'C01', 'C02']
    
    # Find matching columns
    selected_columns = [col for col in possible_columns if col in df.columns]
    
    # Ensure all selected columns are found, otherwise skip this file
    if len(selected_columns) < len(possible_columns):
        print(f"Warning: Not all required columns found in {file_path}. Skipping this file.")
        continue
    
    # Select the relevant columns and drop rows with NaN values
    filtered_df = df[selected_columns].dropna()
    
    # Check if filtered_df is empty after dropping NaN values
    if filtered_df.empty:
        print(f"Warning: No valid data after dropping NaN values in {file_path}. Skipping this file.")
        continue
    
    # Rename columns for easier reference
    filtered_df.columns = ['ID', 'Date', 'Morning PEFR', 'Afternoon PEFR']
    
    # Convert 'Date' to datetime format and handle NaT values
    filtered_df['Date'] = pd.to_datetime(filtered_df['Date'], format='%Y-%m-%d', errors='coerce')
    filtered_df = filtered_df.dropna(subset=['Date'])  # Drop rows where 'Date' conversion failed

    # Check if filtered_df is empty after dropping invalid dates
    if filtered_df.empty:
        print(f"Warning: No valid dates found in {file_path} after conversion. Skipping this file.")
        continue

    # Create a 'Days' column based on the difference from the minimum date in each file
    filtered_df['Days'] = (filtered_df['Date'] - filtered_df['Date'].min()).dt.days
    
    # Append this DataFrame to the list
    all_data.append(filtered_df[['Days', 'Morning PEFR', 'Afternoon PEFR']])

# Combine all data into a single DataFrame
combined_df = pd.concat(all_data, ignore_index=True)

# Check if combined data is empty
if combined_df.empty:
    print("No data available for clustering. Exiting.")
else:
    # Step 2: Standardize the combined data
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(combined_df)

    # Step 3: Optional - Use the Elbow Method to find the optimal number of clusters
    inertia = []
    K = range(1, 11)
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(scaled_data)
        inertia.append(kmeans.inertia_)

    # Plot the Elbow Method
    plt.figure(figsize=(8, 6))
    plt.plot(K, inertia, 'bx-')
    plt.xlabel('Number of clusters')
    plt.ylabel('Inertia')
    plt.title('Elbow Method For Optimal k (Combined Data)')
    plt.show()

    # Step 4: Apply K-Means Clustering with the chosen number of clusters
    num_clusters = 3  # Set based on Elbow plot or manually
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    combined_df['Cluster'] = kmeans.fit_predict(scaled_data)

    # Display the clustered data
    print(combined_df.head())

    # Step 5: 3D Visualization of Clusters
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    scatter = ax.scatter(combined_df['Days'], 
                         combined_df['Morning PEFR'], 
                         combined_df['Afternoon PEFR'], 
                         c=combined_df['Cluster'], cmap='viridis', marker='o')
    ax.set_xlabel('Days')
    ax.set_ylabel('Morning PEFR')
    ax.set_zlabel('Afternoon PEFR')
    plt.colorbar(scatter, label='Cluster')
    plt.title('3D Visualization of Clusters Based on Days, Morning PEFR, and Afternoon PEFR')
    plt.show()

    # Step 6: Trend Analysis Over Time
    trend_df = combined_df.groupby(['Days', 'Cluster']).mean().reset_index()

    plt.figure(figsize=(12, 6))
    sns.lineplot(data=trend_df, x='Days', y='Morning PEFR', hue='Cluster', palette='viridis')
    plt.title('Trend Analysis of Morning PEFR Over Time by Cluster')
    plt.xlabel('Days')
    plt.ylabel('Morning PEFR')
    plt.legend(title='Cluster')
    plt.show()

    plt.figure(figsize=(12, 6))
    sns.lineplot(data=trend_df, x='Days', y='Afternoon PEFR', hue='Cluster', palette='viridis')
    plt.title('Trend Analysis of Afternoon PEFR Over Time by Cluster')
    plt.xlabel('Days')
    plt.ylabel('Afternoon PEFR')
    plt.legend(title='Cluster')
    plt.show()

    # Step 7: Display Cluster Centers
    cluster_centers = kmeans.cluster_centers_
    cluster_centers_original = scaler.inverse_transform(cluster_centers)
    centers_df = pd.DataFrame(cluster_centers_original, columns=['Days', 'Morning PEFR', 'Afternoon PEFR'])
    centers_df['Cluster'] = range(len(centers_df))

    print("Cluster Centers (Original Scale):")
    print(centers_df)

    # Visualize the cluster centers in the 3D plot
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    scatter = ax.scatter(combined_df['Days'], 
                         combined_df['Morning PEFR'], 
                         combined_df['Afternoon PEFR'], 
                         c=combined_df['Cluster'], cmap='viridis', marker='o', alpha=0.5)
    ax.scatter(centers_df['Days'], 
               centers_df['Morning PEFR'], 
               centers_df['Afternoon PEFR'], 
               c='red', s=300, marker='X', label='Cluster Centers')
    ax.set_xlabel('Days')
    ax.set_ylabel('Morning PEFR')
    ax.set_zlabel('Afternoon PEFR')
    plt.colorbar(scatter, label='Cluster')
    plt.title('3D Visualization of Clusters and Cluster Centers')
    plt.legend()
    plt.show()

    # Step 8: (Optional) Save the clustered combined data to a new file
    output_path = os.path.join(directory_path, "combined_clustered_data.xlsx")
    combined_df.to_excel(output_path, index=False)
    print(f"Clustered combined data saved to: {output_path}")
# Out:
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-001 (2020-02-05).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-001 (2020-02-05).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-016 (2018-01-31).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-016 (2018-01-31).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-070 (2019-10-16).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-070 (2019-10-16).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-071 (2018-08-31).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-071 (2018-08-31).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-072 (2021-10-18).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-072 (2021-10-18).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-073 (2021-04-03).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/clustered_SB-073 (2021-04-03).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/combined_clustered_data.xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/combined_clustered_data.xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-001 (2020-02-05).xlsx
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-002 (2017-01-29).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-002 (2017-01-29).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-003 (2020-03-29).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-003 (2020-03-29).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-004 (2021-09-04).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-004 (2021-09-04).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-005 (2017-03-11).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-005 (2017-03-11).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-006 (2020-01-08).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-006 (2020-01-08).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-007 (2017-05-15).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-007 (2017-05-15).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-008 (2021-06-30).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-008 (2021-06-30).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-009 (2019-04-09).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-009 (2019-04-09).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-010 (2017-07-24).xlsx
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-011 (2022-01-19).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-011 (2022-01-19).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-012 (2018-05-15).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-012 (2018-05-15).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-013 (2017-03-18).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-013 (2017-03-18).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-014 (2022-01-10).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-014 (2022-01-10).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-015 (2018-05-20).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-015 (2018-05-20).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-016 (2018-01-31).xlsx
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-017 (2021-11-30).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-017 (2021-11-30).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-018 (2017-09-13).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-018 (2017-09-13).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-019 (2018-05-26).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-019 (2018-05-26).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-020 (2017-10-12).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-020 (2017-10-12).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-021 (2017-09-12).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-021 (2017-09-12).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-022 (2021-04-30).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-022 (2021-04-30).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-023 (2020-04-06).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-023 (2020-04-06).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-024 (2017-08-30).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-024 (2017-08-30).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-025 (2019-10-14).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-025 (2019-10-14).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-026 (2018-02-26).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-026 (2018-02-26).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-028 (2018-08-08).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-028 (2018-08-08).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-029 (2020-04-19).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-029 (2020-04-19).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-031 (2018-05-15).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-031 (2018-05-15).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-032 (2017-10-10).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-032 (2017-10-10).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-033 (2020-03-28).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-033 (2020-03-28).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-035 (2017-09-11).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-035 (2017-09-11).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-036 (2019-10-13).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-036 (2019-10-13).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-037 (2018-07-23).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-037 (2018-07-23).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-039 (2017-05-31).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-039 (2017-05-31).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-040 (2021-09-30).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-040 (2021-09-30).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-042 (2019-05-20).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-042 (2019-05-20).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-043 (2020-04-01).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-043 (2020-04-01).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-044 (2019-04-03).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-044 (2019-04-03).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-046 (2017-10-11).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-046 (2017-10-11).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-047 (2020-06-08).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB-047 (2020-06-08).xlsx. Skipping this file.
# Processing file: /mnt/c/2024-Data/SCH_asthma_114/SB-048 (2021-04-19).xlsx
# Warning: Not all required columns found in /mnt/c/2024-Data/SCH_asthma_114/SB